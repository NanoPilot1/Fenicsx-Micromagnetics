# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("hyst_out/hysteresis_log.txt")
nmag = np.loadtxt("data.txt")

plt.plot(data[:,1]*4*np.pi*1e-4,data[:,4], color='red')
plt.plot(nmag[:,0],nmag[:,1], linestyle='dashed', color='blue')

plt.xlabel("H_x (mT)")
plt.ylabel("m_x")
plt.show()
